# %%
import pandas as pd

# %%
data1 = pd.read_csv('prices_round_1_day_-1.csv', sep=';')
data2 = pd.read_csv(f'prices_round_1_day_-2.csv', sep=';')

# %%
data1
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -1          0  AMETHYSTS        10002             1       9996.0
# 1       -1          0  STARFRUIT         5045             1       5040.0
# 2       -1        100  STARFRUIT         5040            24          NaN
# 3       -1        100  AMETHYSTS         9996             2       9995.0
# 4       -1        200  AMETHYSTS         9995            20          NaN
# ...    ...        ...        ...          ...           ...          ...
# 19995   -1     999700  AMETHYSTS         9995            26          NaN
# 19996   -1     999800  STARFRUIT         5036            20          NaN
# 19997   -1     999800  AMETHYSTS         9995            20          NaN
# 19998   -1     999900  AMETHYSTS         9996             2       9995.0
# 19999   -1     999900  STARFRUIT         5036            31          NaN
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
data_starfruit1 = data1.loc[data1['product'] == 'STARFRUIT']
data_starfruit2 = data2.loc[data2['product'] == 'STARFRUIT']

# %%
data_amethysts = data1[data1['product'] == 'AMETHYSTS']

# %%
data_amethysts
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0       -1          0  AMETHYSTS        10002             1       9996.0
# 3       -1        100  AMETHYSTS         9996             2       9995.0
# 4       -1        200  AMETHYSTS         9995            20          NaN
# 6       -1        300  AMETHYSTS         9996             2       9995.0
# 8       -1        400  AMETHYSTS         9996             2       9995.0
# ...    ...        ...        ...          ...           ...          ...
# 19990   -1     999500  AMETHYSTS        10000             5       9996.0
# 19993   -1     999600  AMETHYSTS        10000             4       9996.0
# 19995   -1     999700  AMETHYSTS         9995            26          NaN
# 19997   -1     999800  AMETHYSTS         9995            20          NaN
# 19998   -1     999900  AMETHYSTS         9996             2       9995.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
data_amethysts['ask_volume_1'].describe()
# Out:
# count    10000.000000
# mean         8.273300
# std         10.184615
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%         20.000000
# max         30.000000
# Name: ask_volume_1, dtype: float64

# %%
data_starfruit1
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 1       -1          0  STARFRUIT         5045             1       5040.0
# 2       -1        100  STARFRUIT         5040            24          NaN
# 5       -1        200  STARFRUIT         5041             2       5040.0
# 7       -1        300  STARFRUIT         5040            31          NaN
# 9       -1        400  STARFRUIT         5039            27          NaN
# ...    ...        ...        ...          ...           ...          ...
# 19991   -1     999500  STARFRUIT         5041             2       5040.0
# 19992   -1     999600  STARFRUIT         5040             5       5037.0
# 19994   -1     999700  STARFRUIT         5037            26          NaN
# 19996   -1     999800  STARFRUIT         5036            20          NaN
# 19999   -1     999900  STARFRUIT         5036            31          NaN
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
data_starfruit2
# Out:
#        day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 1       -2          0  STARFRUIT         4997            26          NaN
# 3       -2        100  STARFRUIT         5000             5       4998.0
# 4       -2        200  STARFRUIT         4997             1       4996.0
# 7       -2        300  STARFRUIT         4996            27          NaN
# 9       -2        400  STARFRUIT         4995            20          NaN
# ...    ...        ...        ...          ...           ...          ...
# 19990   -2     999500  STARFRUIT         5041             2       5040.0
# 19993   -2     999600  STARFRUIT         5040            30          NaN
# 19994   -2     999700  STARFRUIT         5040            22          NaN
# 19996   -2     999800  STARFRUIT         5041             1       5040.0
# 19998   -2     999900  STARFRUIT         5044             4       5040.0
#
#        bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
data_starfruit1['mid_price'].plot()
# Out:
# <Axes: >

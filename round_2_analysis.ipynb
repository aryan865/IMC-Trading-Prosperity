# %%
import pandas as pd
from scipy.stats import zscore

# %%
data = pd.read_csv("prices_round_2_day_0.csv", sep=';')

# %%
data
# Out:
#        timestamp  ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF  \
# 0              0  1111.75             1.5           10.5           -2.0
# 1            100  1111.75             1.5           10.5           -2.0
# 2            200  1109.75             1.5           10.5           -2.0
# 3            300  1109.25             1.5           10.5           -2.0
# 4            400  1110.75             1.5           10.5           -2.0
# ...          ...      ...             ...            ...            ...
# 9996      999600   988.25             1.3           10.5           -2.6
# 9997      999700   988.00             1.3           10.5           -2.6
# 9998      999800   988.75             1.3           10.5           -2.6
# 9999      999900   986.75             1.3           10.5           -2.6
# 10000    1000000   985.75             1.3           10.5           -2.6
#
#         SUNLIGHT   HUMIDITY  DAY
# 0      4500.0000  95.000000    0
# 1      4500.0356  94.995990    0
# ...

# %%
import matplotlib.pyplot as plt

# %%
df = data

# %%
df['SUNLIGHT_zscore'] = zscore(df['SUNLIGHT'])
df['HUMIDITY_zscore'] = zscore(df['HUMIDITY'])
df['IMPORT_TARIFF_zscore'] = zscore(df['IMPORT_TARIFF'])
df['EXPORT_TARIFF_zscore'] = zscore(df['EXPORT_TARIFF'])
df['TRANSPORT_FEES_zscore'] = zscore(df['TRANSPORT_FEES'])
df['ORCHIDS_zscore'] = zscore(df['ORCHIDS'])

# %%
df
# Out:
#        timestamp  ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF  \
# 0              0  1111.75             1.5           10.5           -2.0
# 1            100  1111.75             1.5           10.5           -2.0
# 2            200  1109.75             1.5           10.5           -2.0
# 3            300  1109.25             1.5           10.5           -2.0
# 4            400  1110.75             1.5           10.5           -2.0
# ...          ...      ...             ...            ...            ...
# 9996      999600   988.25             1.3           10.5           -2.6
# 9997      999700   988.00             1.3           10.5           -2.6
# 9998      999800   988.75             1.3           10.5           -2.6
# 9999      999900   986.75             1.3           10.5           -2.6
# 10000    1000000   985.75             1.3           10.5           -2.6
#
#         SUNLIGHT   HUMIDITY  DAY  SUNLIGHT_zscore  HUMIDITY_zscore  \
# ...

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

# Plot parameter 1
plt.plot(df['timestamp'], df['SUNLIGHT_zscore'], label='Sunlight')

# Plot parameter 2
plt.plot(df['timestamp'], df['HUMIDITY_zscore'], label='Humidity')


plt.plot(df['timestamp'], df['IMPORT_TARIFF_zscore'], label='Import')
plt.plot(df['timestamp'], df['EXPORT_TARIFF_zscore'], label='Export')
plt.plot(df['timestamp'], df['TRANSPORT_FEES_zscore'], label='Transport')
plt.plot(df['timestamp'], df['ORCHIDS_zscore'], label='Orchids')

# Add labels and title
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Sunlight and Humidity Over Time')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
df['x'] = 0.27043254*df['SUNLIGHT_zscore'] + 0.3961525 *df['HUMIDITY_zscore']+ 0.25699567*df['IMPORT_TARIFF_zscore']+0.22466134*df['EXPORT_TARIFF_zscore']-0.23863818*df['TRANSPORT_FEES_zscore']

# %%
df
# Out:
#        timestamp  ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF  \
# 0              0  1111.75             1.5           10.5           -2.0
# 1            100  1111.75             1.5           10.5           -2.0
# 2            200  1109.75             1.5           10.5           -2.0
# 3            300  1109.25             1.5           10.5           -2.0
# 4            400  1110.75             1.5           10.5           -2.0
# ...          ...      ...             ...            ...            ...
# 9996      999600   988.25             1.3           10.5           -2.6
# 9997      999700   988.00             1.3           10.5           -2.6
# 9998      999800   988.75             1.3           10.5           -2.6
# 9999      999900   986.75             1.3           10.5           -2.6
# 10000    1000000   985.75             1.3           10.5           -2.6
#
#         SUNLIGHT   HUMIDITY  DAY  SUNLIGHT_zscore  HUMIDITY_zscore  \
# ...

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

# Plot parameter 1
plt.plot(df['timestamp'], df['x'], label='x')



plt.plot(df['timestamp'], df['ORCHIDS_zscore'], label='Orchids')

# Add labels and title
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Parameter x and orchids')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import pandas as pd
import statsmodels.api as sm
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_25152\878524530.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
df0 = pd.read_csv('prices_round_3_day_0.csv', index_col='timestamp', delimiter=';')
df1 = pd.read_csv('prices_round_3_day_1.csv', index_col='timestamp', delimiter=';')
df2 = pd.read_csv('prices_round_3_day_2.csv', index_col='timestamp', delimiter=';')
df = pd.concat([df0,df1,df2], ignore_index=True).reset_index(drop=True)
df.head(10)
# Out:
#    day       product  bid_price_1  bid_volume_1  bid_price_2  bid_volume_2  \
# 0    0     CHOCOLATE         7999           111          NaN           NaN
# 1    0  STRAWBERRIES         3999           210          NaN           NaN
# 2    0         ROSES        14999            72          NaN           NaN
# 3    0   GIFT_BASKET        71348            19      71347.0          24.0
# 4    0   GIFT_BASKET        71344             1      71343.0          12.0
# 5    0     CHOCOLATE         8001            52       8000.0          95.0
# 6    0         ROSES        14999            66          NaN           NaN
# 7    0  STRAWBERRIES         3999           265          NaN           NaN
# 8    0         ROSES        15000            61          NaN           NaN
# 9    0   GIFT_BASKET        71344             4      71339.0           1.0
#
#    bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  ask_price_2  \
# 0          NaN           NaN         8001           111          NaN
# 1          NaN           NaN         4001           210          NaN
# 2          NaN           NaN        15001            72          NaN
# 3          NaN           NaN        71362            19      71363.0
# 4      71342.0          20.0        71355             1      71356.0
# 5          NaN           NaN         8002           147          NaN
# 6          NaN           NaN        15001            66          NaN
# 7          NaN           NaN         4000           265          NaN
# 8          NaN           NaN        15001            21      15002.0
# 9      71338.0          14.0        71350             1      71351.0
#
#    ask_volume_2  ask_price_3  ask_volume_3  mid_price  profit_and_loss
# 0           NaN          NaN           NaN     8000.0              0.0
# 1           NaN          NaN           NaN     4000.0              0.0
# 2           NaN          NaN           NaN    15000.0              0.0
# 3          24.0          NaN           NaN    71355.0              0.0
# 4          12.0      71357.0          20.0    71349.5              0.0
# 5           NaN          NaN           NaN     8001.5              0.0
# 6           NaN          NaN           NaN    15000.0              0.0
# 7           NaN          NaN           NaN     3999.5              0.0
# 8          40.0          NaN           NaN    15000.5              0.0
# 9          14.0      71352.0          21.0    71347.0              0.0

# %%
df_chocolate = df.loc[df['product']=='CHOCOLATE'][['mid_price']]
df_gift_basket = df.loc[df['product']=='GIFT_BASKET'][['mid_price']]
df_strawberries = df.loc[df['product']=='STRAWBERRIES'][['mid_price']]
df_roses = df.loc[df['product']=='ROSES'][['mid_price']]

# %%
x = list(np.log(df_roses['mid_price']))
x_const = sm.add_constant(x)
y = list(np.log(df_gift_basket['mid_price']))
linear_reg = sm.OLS(y,x_const)
results = linear_reg.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.727
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                 7.977e+04
# Date:                Wed, 17 Apr 2024   Prob (F-statistic):               0.00
# Time:                        01:25:41   Log-Likelihood:             1.1987e+05
# No. Observations:               30000   AIC:                        -2.397e+05
# Df Residuals:                   29998   BIC:                        -2.397e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.9059      0.022    221.324      0.000       4.862       4.949
# x1             0.6533      0.002    282.433      0.000       0.649       0.658
# ==============================================================================
# Omnibus:                     1015.262   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              539.069
# Skew:                          -0.148   Prob(JB):                    8.76e-118
# Kurtosis:                       2.413   Cond. No.                     8.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
beta = results.params[1]
alpha = results.params[0]

# %%
y_pred = np.log(df_roses['mid_price'])*beta + alpha

# %%
df_pairs = pd.DataFrame(np.log(df_gift_basket['mid_price']).to_numpy() - (np.log(df_roses['mid_price'])*beta-alpha).to_numpy())

df_pairs.columns = ['spread']
df_pairs.plot(figsize =(15,10))

plt.ylabel('spread')
# Out:
# Text(0, 0.5, 'spread')

# %%
df_pairs['mean'] = df_pairs['spread'].mean()
df_pairs['upper'] = df_pairs['mean'] + 0.5*df_pairs['spread'].std()
df_pairs['lower'] = df_pairs['mean'] - 0.5*df_pairs['spread'].std()

# %%
df_pairs.plot(figsize =(15,10),style=['g', '--r', '--b', '--b'])
# Out:
# <Axes: >

# %%
df_pairs['buy'] = df_pairs['spread'][((df_pairs['spread'] < df_pairs['lower']) & (df_pairs['spread'].shift(1) > df_pairs['lower']) | 
                          (df_pairs['spread'] <  df_pairs['mean']) & (df_pairs['spread'].shift(1) >  df_pairs['mean']))]

df_pairs['sell'] = df_pairs['spread'][((df_pairs['spread'] > df_pairs['upper']) & (df_pairs['spread'].shift(1) < df_pairs['upper']) | 
                           (df_pairs['spread'] >  df_pairs['mean']) & (df_pairs['spread'].shift(1) <  df_pairs['mean']))]
df_pairs.plot(figsize =(17,10), style=['g', '--r', '--b', '--b', 'm^','cv'])
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt

def backtest_pairs_trading(df_pairs, initial_capital):
    # Initialize capital and positions
    capital = initial_capital  # Initial capital
    position = 0               # Initial position size

    # Lists to store trade information
    dates = []
    positions = []
    cash_values = []

    # Loop through each row in df_pairs and execute trades based on buy and sell signals
    for i, row in df_pairs.iterrows():
        if pd.notnull(row['buy']):
            # Buy signal
            shares_to_buy = capital // row['buy']  # Calculate number of shares to buy
            cost = shares_to_buy * row['buy']      # Calculate cost of buying shares
            capital -= cost                        # Reduce capital by the cost of buying shares
            position += shares_to_buy              # Increase position size
            dates.append(i)
            positions.append(position)
            cash_values.append(capital)
        elif pd.notnull(row['sell']):
            # Sell signal
            capital += position * row['sell']      # Increase capital by selling all shares
            position = 0                           # Reset position size to zero
            dates.append(i)
            positions.append(position)
            cash_values.append(capital)

    # Convert lists to pandas Series for plotting
    dates_series = pd.Series(dates)
    positions_series = pd.Series(positions)
    cash_values_series = pd.Series(cash_values)

    # Plot the positions and cash values over time
    plt.figure(figsize=(15, 10))
    plt.plot(dates_series, positions_series, 'g-', label='Position')
    plt.plot(dates_series, cash_values_series, 'b-', label='Cash Value')
    plt.xlabel('Date')
    plt.ylabel('Amount')
    plt.title('Backtesting Results')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Calculate final account balance
    final_account_balance = capital + (position * df_pairs['spread'].iloc[-1])

    # Calculate total profit or loss
    total_profit_loss = final_account_balance - initial_capital

    # Calculate return on investment (ROI)
    ROI = (total_profit_loss / initial_capital) * 100

    return final_account_balance, total_profit_loss, ROI

# Example usage:
initial_capital = 100000  # Initial capital
final_account_balance, total_profit_loss, ROI = backtest_pairs_trading(df_pairs, initial_capital)

print("Final Account Balance:", final_account_balance)
print("Total Profit/Loss:", total_profit_loss)
print("Return on Investment (ROI):", ROI, "%")
# Out:
# Final Account Balance: 100025.26481000253
# Total Profit/Loss: 25.264810002525337
# Return on Investment (ROI): 0.02526481000252534 %
